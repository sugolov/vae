# %%
import jax
import jax.numpy as jnp
import equinox as eqx
import optax
import numpy as np

from vae.train.train_vqvae import load_checkpoint

load_checkpoint("weights/simclr_cifar_v1_final", seed=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 9
#       5 import numpy as np
#       7 from vae.train.train_vqvae import load_checkpoint
# ----> 9 load_checkpoint("weights/simclr_cifar_v1_final", seed=0)
#
# File ~/source/vae/vae/train/train_vqvae.py:146, in load_checkpoint(path, seed)
#     132 key = jax.random.key(seed)
#     133 model = VQVAE(
#     134     key=key,
#     135     in_channels=3,
#    (...)    143     epsilon=1e-5
#     144 )
# --> 146 model = eqx.tree_deserialise_leaves(path + "_model.eqx", model)
#     148 optimizer = optax.adam(learning_rate=args.lr)
#     149 opt_state = optimizer.init(eqx.filter(model, eqx.is_array))
#
# File ~/source/vae/.venv/lib/python3.11/site-packages/equinox/_serialisation.py:333, in tree_deserialise_leaves(path_or_file, like, filter_spec, is_leaf)
#     328 with jax.ensure_compile_time_eval():
# ...
